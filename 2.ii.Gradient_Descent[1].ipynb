# %% [markdown]
# # Name : Gobinath Periyasamy
# # Roll No : CS21M501

# %% [markdown]
# ## (2) ii. Code the gradient descent algorithm with suitable step size to solve the least squares algorithms and plot kwt − wMLk2 as a function of t. What do you observe?

# %% [markdown]
# ### Gradient Descent Algorithm

# %%
# import libraries

import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn import cluster,datasets, mixture
from sklearn.model_selection import train_test_split
from scipy.stats import multivariate_normal
from numpy import linalg as LA

# %% [markdown]
# ### A2Q2 Train Data

# %%
# import Excel A2Q2 data data:
df_train = pd.read_csv("A2Q2Data_train.csv",header = None)
df_train
# Out:
#           0         1         2         3         4        5         6    \
# 0     0.58351  0.379390  0.839750  0.086861  0.611920  0.39203  0.189640
# 1     0.86622  0.451350  0.934790  0.235810  0.504880  0.49742  0.117220
# 2     0.39142  0.919950  0.138730  0.991810  0.543670  0.98449  0.340260
# 3     0.79553  0.278540  0.228900  0.789290  0.492220  0.67084  0.769410
# 4     0.65223  0.966650  0.179850  0.354060  0.840420  0.92891  0.014597
# ...       ...       ...       ...       ...       ...      ...       ...
# 9995  0.13627  0.056966  0.229530  0.343080  0.019914  0.29071  0.124340
# 9996  0.95662  0.141930  0.978510  0.782700  0.198780  0.29844  0.331600
# 9997  0.89209  0.997530  0.880430  0.813160  0.294460  0.40088  0.198950
# 9998  0.70381  0.422940  0.259230  0.230480  0.710920  0.27516  0.843470
# 9999  0.36578  0.028173  0.021793  0.593970  0.521400  0.47722  0.838550
#
#            7        8         9    ...      91       92        93       94   \
# ...

# %% [markdown]
# ### Gradient Descent Algorithm

# %%
# Data import and Manipulation done in previous problem
feature_train  = 0
X_train = df_train.iloc[:,:-1]
Y_train = df_train.iloc[::,-1:]

f_train = X_train.shape[1]
n_train = len(df_train)
print(f_train,n_train)
X_train = X_train.to_numpy()
y_train = Y_train.to_numpy()
w_ml = np.dot(np.dot(LA.inv(np.dot(X_train.T, X_train)),X_train.T),y_train)
print("w_ml: ",w_ml.reshape(f_train),'\n')

print("Mean Squared Error on train set using w_ML ",(1/n_train)*(LA.norm(X_train@w_ml - y_train))**2)
# Out:
# 100 10000
# w_ml:  [-7.84961009e-03 -1.36715320e-02 -3.61656438e-03  2.64909160e-03
#   1.88551446e-01  2.65314657e-03  9.46531786e-03  1.79809481e-01
#   3.73757317e-03  4.99608944e-01  8.35836265e-03  4.29108775e-03
#   1.42141179e-02  3.94232414e-03  9.36795890e-03 -1.12038274e-03
#   3.35727500e-03  1.16152212e-03 -9.40884707e-03 -2.45575476e-03
#  -1.17409629e-02 -1.01960612e-02  7.95771321e-03 -1.00574854e-02
#   6.04882939e-03 -4.67345192e-03 -3.09091547e-03  8.14909193e-03
#   1.20264599e-02 -6.82458163e-03 -8.65405539e-03  9.86273479e-04
#   4.92968011e-03  5.99772461e-03 -1.34667860e-02  1.07075729e-03
#   1.32745992e-02 -1.14148742e-02 -2.01056697e-02  5.85096240e-01
#   4.94483247e-04 -7.86666920e-04 -2.71926574e-03 -9.54021938e-03
#  -5.44161058e-03  9.80679209e-03 -6.72540624e-03 -4.45414276e-04
#   6.98516508e-03  3.16138907e-02  4.51763485e-01 -8.75221380e-03
#   2.55167390e-03  4.24921150e-03  2.89847927e-01  7.03723255e-03
# ...

# %%
# import Excel A2Q1 data:
df_test = pd.read_csv("A2Q2Data_test.csv",header = None)
df_test
# Out:
#          0         1        2         3         4         5        6    \
# 0    0.21302  0.446210  0.51432  0.219750  0.495440  0.463670  0.26007
# 1    0.32563  0.703990  0.31970  0.045240  0.869680  0.131360  0.47664
# 2    0.49539  0.623570  0.58121  0.879160  0.930960  0.203040  0.35752
# 3    0.88875  0.013187  0.87982  0.858160  0.793920  0.792390  0.76522
# 4    0.15178  0.540760  0.26896  0.006752  0.101020  0.342080  0.86855
# ..       ...       ...      ...       ...       ...       ...      ...
# 495  0.10578  0.870530  0.66376  0.570310  0.691110  0.065131  0.25840
# 496  0.36756  0.673490  0.54089  0.932350  0.037031  0.806840  0.50789
# 497  0.24582  0.320620  0.79933  0.743320  0.314150  0.713150  0.90045
# 498  0.31768  0.937750  0.91269  0.840630  0.301710  0.600530  0.59427
# 499  0.46955  0.337400  0.58504  0.460880  0.389140  0.965600  0.82079
#
#          7         8        9    ...      91        92       93        94   \
# ...

# %%
# Assign X_train, Y_train data

feature_test  = 0
X_test = df_test.iloc[:,:-1]
Y_test = df_test.iloc[::,-1:]
#iterating through the whole file
for row_test in X_test:
    feature_test = feature_test + 1
f_test = feature_test
n_test = len(df_test)

# %%
print(f_test,n_test)
X_test = X_test.to_numpy()
y_test = Y_test.to_numpy()
# Out:
# 100 500

# %%
#  least squares solution wML to compare with
print("Mean Squared Error on train set using w_ML ",(1/n_test)*(LA.norm(X_test@w_ml - y_test))**2)
# Out:
# Mean Squared Error on train set using w_ML  0.3707273111697899

# %% [markdown]
# ### Gradient Descent Formula

# %%
eta = 70e-7
w_grad = np.random.randn(f_train,1)
loss1 = []
diff = []

for i in range(1100):
    w_grad = w_grad -eta * (X_train.T@(X_train@w_grad - y_train))
    diff.append(LA.norm(w_grad - w_ml))
    
diff = np.array(diff)
diff
# Out:
# array([10.24119539, 10.18013921, 10.11979146, ...,  0.02342198,
#         0.0232992 ,  0.02317707])

# %% [markdown]
# ### plot abs(w^t − wML) Square Norm as a function of t

# %%
plt.figure(figsize = (6,6))
plt.xlabel('time t')
plt.ylabel('Gradient Descent')
plt.title('Gradient Descent \n')
plt.plot(diff)
plt.grid()
# visualizing plot using matplotlib.pyplot library
plt.show()

# %%
# Finding 
print("Final Mean Squared Error on train set using w_Grad ",(1/n_train)*(LA.norm(X_train@w_grad - y_train))**2)
# Out:
# Final Mean Squared Error on train set using w_Grad  0.03972666337134663

# %%
print("Final Mean Squared Error on test set using w_Grad ",(1/n_test)*(LA.norm(X_test@w_grad - y_test))**2)
# Out:
# Final Mean Squared Error on test set using w_Grad  0.3720474796794926

# %%
w_grad.reshape(-1)
# Out:
# array([-1.08953588e-02, -1.15370800e-02,  1.63677538e-03,  2.08880451e-03,
#         1.87457054e-01,  9.08123253e-05,  6.55013011e-03,  1.76151996e-01,
#         4.66399179e-03,  4.91936427e-01,  8.40733417e-03,  1.10430028e-03,
#         2.07168226e-02,  5.27252247e-03,  1.31739951e-02, -3.55197347e-03,
#         3.96561552e-03,  4.82937097e-03, -9.32950581e-03, -3.80258344e-03,
#        -1.37251472e-02, -7.69725971e-03,  9.45840232e-03, -8.03165886e-03,
#         7.38951355e-03, -6.61017614e-03, -5.11329918e-03,  7.69384080e-03,
#         1.14183634e-02, -4.43409192e-03, -1.15343796e-02,  2.71229006e-03,
#         9.99681596e-03,  6.40806713e-03, -1.62168234e-02,  1.05190233e-04,
#         1.43734958e-02, -1.34426314e-02, -2.12228649e-02,  5.86689495e-01,
#         2.37874109e-03, -3.50233443e-03, -2.77385680e-03, -7.74412898e-03,
#        -1.89431048e-03,  1.14276765e-02, -6.24036583e-03, -3.83802433e-03,
# ...

# %% [markdown]
# ## Final Mean Squared Error on train set using Gradient Descent : 0.03974304674769516

# %% [markdown]
# ## Final Mean Squared Error on test set using Gradient Descent  :  0.3691127812548705

# %% [markdown]
# ### What do you observe?

# %% [markdown]
# The Mean Sqaured Error we get using the Gradient descent is equal to the  Mean Sqaured Error found using  least squares solution wML.

# %% [markdown]
# And  plot abs(w^t − wML) Square Norm as a function of t gives us the view how it descents towards the Minimum Value
